# %%
import matplotlib.pyplot as plt

import numpy as np

# %% [markdown]
# ## Broadcast

# %%
a1 = np.arange(1,10).reshape(3,3)

# %%
a2 = np.array([10,20,30])

# %%
a1+a2

# %%
a2+a1

# %%
aa = np.array((0,10,20,30))
aa, aa[:,None]

# %%
aa.reshape(4,1)

# %%
bb = np.array((0,1,2))
y = aa[:, None] + bb

print(y)

# %% [markdown]
# # Working with files

# %%
arr = np.random.rand(4, 5)
arr

# %%
np.save("data1",arr)
np.savetxt("data1.txt",arr)
np.savez("data1", arr)

# %%
arr2=np.load("data1.npy")
arr2

# %%
arr3 = np.loadtxt("data1.txt")

# %%
arr3

# %% [markdown]
# ## Custom type

# %%
a = np.array([(1,2.0,"Hello"), (2,3.0,"World")])
a

# %%
dt = np.dtype("i4,f8,S5")
print(dt.fields)
a =np.array([(1,2.0,"Hello"), (2,3.0,"World")], dtype=dt)
print(a)

# %%
a['f0']*=10

# %%
a

# %%
dt2=np.dtype([('id','i4'), ('weight', 'f4'),('name', 'U10')])

# %%
arr3 = np.loadtxt("datacust.txt",dtype=dt2,delimiter=',')

# %%
arr3

# %%
arr3['id']

# %%
arr3['weight']

# %%
arr4 = np.vstack((arr3['id'],arr3['weight']))

# %%
arr4

# %%
arr4.T

# %% [markdown]
# ## Object type

# %%
class Complex:
    def __init__(self,real = 0,img = 0):
        self.__real = real
        self.__img = img
    def __add__(self,b):
        # assert isinstance(b, Complex)
        res = Complex(self.__real +b.__real, self.__img + b.__img)
        return res
    def __str__(self):
        if(self.__img >=0):
            str1 = " + "
            num = self.__img
        else:
            str1 = " - "
            num = self.__img * -1
        st = ("Complex " + str(self.__real) + 
                    str1 + str(num) + "i ")
        return st

    
a = Complex(10,-20)
b = Complex(9,7)


aa = np.array([a, b], object)
bb = np.array([a, b], object)
v=aa+bb
print(v[0])

# %% [markdown]
# ## Indexing Tricks

# %%
s=np.r_  # the RClass instance numpy exposes; np.lib.index_tricks is private since numpy 2
s[2:5]

# %%
np.r_[1:4]

# %%
np.r_[0]

# %%
np.r_[1]

# %%
np.r_[1:20]

# %%
np.r_[1:20:5]

# %%
np.r_[1:20:5j]

# %%
np.r_[1:3,5:8,10:13]

# %%
np.r_[2:4,5:15:20j,20:30:2]

# %%
np.c_[2:10]

# %%
np.c_[2:15,3:16,100:113]

# %% [markdown]
# <br/><br/>
# ## Views

# %%
a = np.array([[0, 4, 5, 8],
              [1, 4, 5, 8],
              [1, 4, 5, 8],
              [1, 4, 5, 8]],'i1')
              
b = a.view('i4')

d=[hex(val.item()) for val in b.flat]
print(d)

# %%
b

# %%
a.tobytes()

# %%
b.tobytes()

# %% [markdown]
# <br><br><br>
# ## Universal functions

# %%
a=np.array([1,2,3])
b=np.array([3,4,5])

c = np.add.__call__(a,b)
c

# %%
np.add.accumulate(a)

# %%
x = np.array([[1, 5, 6, 10], [0, 6, 16, 8]])

# %%
x

# %%
np.add.accumulate(x)

# %%
np.add.accumulate(x,axis=1)

# %% [markdown]
# ## diff

# %%
x = np.array([[1, 5, 6, 10], [0, 6, 16, 8],[2,10,10,9]])
x

# %%
np.diff(x)

# %%
np.diff(x, axis=0)

# %% [markdown]
# ## masking

# %%
a=np.random.randint(0,2,(4,5))

a[a==0]=100

# %%
a==100

# %%
a

# %%
b=np.random.randint(5,11,(4,5))

c=np.where(a==100,a,b)

# %%
b

# %%
c

# %% [markdown]
# ## Linear Algebra

# %%
a2=np.array([[1,2],[3,4]])

# %%
np.linalg.det(a2)

# %%
np.linalg.inv(a2) # error

# %%
np.linalg.norm(a2)

# %%
b = np.array([5,11])

# %%
np.linalg.solve(a2,b)

# %%
np.linalg.inv(a2).dot(b)

# %% [markdown]
# # polynomials

# %%
fn = np.poly1d([4,3,1]) # fn = 4x**2 + 3x + 1 
# np.polynomial.Chebyshev(1)

# %%
fn(3)

# %%
fn2 = np.poly((2,2))

# %%
fn2

# %%
fn = np.poly1d(fn2)

# %%
fn(10)

# %%
fn.roots

# %%
a = np.arange(1,21)
b = np.array([2,4,5,9,8,10,14,16,18,16,17,16,14,13,12,10,8,6,5,3])
x = np.polyfit(a,b,2)

# %%
x

# %%
p = np.poly1d(x)

# %%
plt.plot(a,b, 'o',a,p(a))

# %% [markdown]
# # Vectorize

# %%
def vec1(a):
    if a>200:
        return 200
    elif a<50:
        return 50
    else:
        return a

# %%
arr = np.random.randint(1,255,(5,10))

# %%
arr

# %%
#vec1(arr) # error

# %%
fn = np.vectorize(vec1)

# %%
fn(arr)

# %%
arr[arr > 100] = 100

# %%
arr[arr < 60] = 60

# %%
arr
