# %%
import numpy as np
import pandas as pd

# %%
samp=np.random.randint(100, 600,size=(4,5))

# %%
df22=pd.DataFrame(samp)

# %%
samp

# %%
df22

# %%
df=pd.DataFrame(samp,index=['avi','dani','rina','dina'], 
                        columns=['Jan','Feb','Mar','Apr','May'])

# %%
df2=pd.DataFrame(samp,index=['eli','yosi','rani','meir'], 
                        columns=['Jan','Feb','Mar','Apr','May'])

# %%
df

# %%
df['Jan']

# %%
df['Jan']['avi']

# %%
df

# %%
df.loc['avi':'rina':2,'Jan':'Apr':2]

# %% [markdown]
# ## Selection and Indexing
#
# Let's learn the various methods to grab data from a DataFrame

# %%
# Pass a list of column names
df[['Jan','May']]

# %%
df['Jan']['avi']

# %%
df.Feb.avi

# %%
df.Feb[df.Feb>300]

# %% [markdown]
# DataFrame Columns are just Series

# %%
type(df['May'])

# %%
type(df)

# %%
type(df['May']>300)

# %%
type(df['May']['avi'])

# %% [markdown]
# ### More options

# %%
df['Jan']['rina'] = 300
df['Jan']['avi'] = 300

# %%
df

# %%
df['Jan'].unique()

# %%
df['Jan'].nunique()

# %%
df['Jan'].value_counts()

# %%
df['Jan'][1:3]

# %%
df.loc['dani':,'Feb':'Apr']

# %%
df

# %%
df.iloc[:3]

# %%
df.iloc[[1,3],[2,3]]

# %%
df.loc[lambda df:df['Jan']>200,:]

# %%
df.loc[:,lambda df: ['Jan','Mar']]

# %%
def add_bonus(x):
    return x*1.2
df.apply(add_bonus)

# %%
df['Jan'].apply(lambda x:x+1000)

# %%
df['Jan'].sum()

# %% [markdown]
# ### Creating a new column:

# %%
df['Expected'] = df['May'] + 20

# %%
df

# %%
df.loc['eli'] = [100,200,300,400,500,600]

# %%
df

# %% [markdown]
# ### Removing Columns

# %%
df.drop('rina',axis=0)

# %%
# Not inplace unless specified!
df

# %%
df.drop('Apr',axis=1,inplace=True)

# %%
df

# %% [markdown]
# ** Selecting Rows**

# %%
df.loc['avi']

# %% [markdown]
# Or select based off of position instead of label

# %%
df.iloc[2]

# %% [markdown]
# ** Selecting subset of rows and columns **

# %%
df.loc['avi','Jan']

# %%
df.loc[['avi','rina'],['Feb','Mar']]

# %%
df.reindex(index=['avi','rina'],columns=['Feb','Mar'])

# %% [markdown]
# ### Conditional Selection
#
# An important feature of pandas is conditional selection using bracket notation, very similar to numpy:

# %%
df

# %%
df>200

# %%
df[df>200]

# %%
df[df['Jan']>200]

# %%
df[df['Jan']>200]['May']

# %%
df[df['Jan']>200][['Jan','Mar']]

# %% [markdown]
# For two conditions you can use | and & with parenthesis:

# %%
df[(df['Jan']>200) & (df['Feb'] > 300)]

# %% [markdown]
# ### sorting

# %%
df

# %%
df.sort_values('Jan')

# %%
df['Jan']['avi'] = np.nan
df['Feb']['dani'] = np.nan
df

# %%
df.isnull()

# %%
df.dropna()

# %%
df.dropna()

# %%
df.fillna(1000)

# %% [markdown]
# ## More Index Details
#
# Let's discuss some more features of indexing, including resetting the index or setting it something else. We'll also talk about index hierarchy!

# %%
df

# %%
# Reset to default 0,1...n index
df.reset_index()

# %%
newind = ['CA', 'NY', 'WY', 'CL', 'TX']

# %%
newind

# %%
df['States'] = newind

# %%
df

# %%
df.set_index(['States','Jan'])

# %%
df

# %%
df.set_index('States',inplace=True)

# %%
df

# %%
df.loc['CA']

# %% [markdown]
# ## Multi-Index and Index Hierarchy
#
# Let us go over how to work with Multi-Index, first we'll create a quick example of what a Multi-Indexed DataFrame would look like:

# %%
# Index Levels
years = ['2016','2016','2016','2016','2017','2017','2017','2017']
q = [1,2,3,4,1,2,3,4]
t = list(zip(years,q))
mi = pd.MultiIndex.from_tuples(t)

# %%
mi

# %%
dfm = pd.DataFrame(np.random.randn(8,2),index=mi,columns=['A','B'])
dfm

# %% [markdown]
# Now let's show how to index this! For index hierarchy we use df.loc[], if this was on the columns axis, you would just use normal bracket notation df[]. Calling one level of the index returns the sub-dataframe:

# %%
dfm.loc['2016']

# %%
dfm.loc['2017'].loc[1]

# %%
dfm.index.names

# %%
dfm.index.names = ['Year','Q']

# %%
dfm

# %%
dfm.xs('2017')

# %%
dfm.xs(('2016',1))

# %%
dfm.xs(1,level='Q')

# %% [markdown]
# ## concat

# %%
df2

# %%
df

# %%
pd.concat([df,df2])

# %%
pd.concat([df,df2],axis=1)

# %%
left = pd.DataFrame({'id': [10, 20, 30, 40],
                     'Name': ['avi', 'dani', 'rina', 'dina'],
                     'City': ['haifa', 'aco', 'tel aviv', 'yafo']})
   
right = pd.DataFrame({'id': [10, 20, 30, 50],
                     'Salary': [1000, 2000, 3000, 4000],
                     'Position': ['CTO', 'CEO', 'COO', 'Marketing']})

# %%
left

# %%
right

# %%
pd.merge(left,right,how='inner',on='id')

# %%
pd.merge(left,right,how='left',on='id')

# %%
pd.merge(left,right,how='right',on='id')

# %%
right

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],'B': ['B0', 'B1', 'B2']},index=['K0', 'K1', 'K2'])
 

right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],'D': ['D0', 'D2', 'D3']},index=['K0', 'K2', 'K3'])

result = left.join(right)

# %%
left

# %%
right

# %%
result

# %%
df3 = pd.DataFrame({'id': [10, 20, 30, 40],
                     'Name': ['avi', 'dani', 'rina', 'dina'],
                     'City': ['haifa', 'haifa', 'tel aviv', 'yafo']})

# %%
df3.groupby('City').count()

# %%
samp=np.random.randint(100, 600,size=(10,10))

# %%
samp

# %%
# %matplotlib inline

# %%
dh=pd.DataFrame(samp,columns=["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"])

# %%
dh

# %%
dh.hist('A')

# %%
dh.plot.area()

# %%
dh['A'].plot.bar()

# %%
import pandas as pd

# %%
df = pd.read_csv("pupils.csv")

# %%
df.head()

# %%
pd.cut(df.income,bins=4,labels=['A','B','C','D'])
